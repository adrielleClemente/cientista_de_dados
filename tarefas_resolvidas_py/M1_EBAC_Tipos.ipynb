# %% [markdown]
# # Exercícios
#
# ### 1. Google Colab

# %%
print('Olá, mundo!')
# Out:
# Olá, mundo!

# %% [markdown]
# ![nova de print(Hello, world!.png](data:image/png;base64,...)

# %% [markdown]
# ### 2. Números

# %%
#(A)
ticket_medio = 320.52
quantidade_total_vendas = 3
print('O total de vendas é:',round(ticket_medio*quantidade_total_vendas))
# Out:
# O total de vendas é: 962

# %%
#(B)
valor_total_vendas = 834.47
ticket_medio = 119.21
print('A quantidade de vendas é:',round(valor_total_vendas/ticket_medio))
# Out:
# A quantidade de vendas é: 7

# %%
#(C)
valor_total_vendas = 15378.12
quantidade_total_vendas = 5
print('O ticket médio é:',round(valor_total_vendas/quantidade_total_vendas))
# Out:
# O ticket médio é: 3076

# %% [markdown]
# ### 3. Strings

# %%
cancao = ('Roda mundo, roda gigante, roda moinho, roda pião.')
print(cancao.lower())
print(cancao.upper())
print(cancao.title())
# Out:
# roda mundo, roda gigante, roda moinho, roda pião.
# RODA MUNDO, RODA GIGANTE, RODA MOINHO, RODA PIÃO.
# Roda Mundo, Roda Gigante, Roda Moinho, Roda Pião.

# %%
noticia = 'Selic vai a 2,75% e supera expectativas; é a primeira alta em 6 anos.'
selic = noticia[12:17]
ano = noticia[-7]
print(f'valor da selic é {selic} e o ano é {ano}.')
# Out:
# valor da selic é 2,75% e o ano é 6.

# %% [markdown]
# ### 4. Booleanos

# %%
a = False
b = True

x = not a & b
# R. É true!
print(x)
# Out:
# True
