# %% [markdown]
# # Módulo 10 tarefa 03
# Considere a mesma base de dados utilizada na tarefa 1 ```previsao_de_renda.csv```.

# %% [markdown]
# 1) Construa um gráfico de barras para avaliar a distribuição das variáveis qualitativas no tempo. Você acha que houve alguma alteração importante a ser investigada?

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('previsao_de_renda.csv')
df.head()
# Out:
#    Unnamed: 0    data_ref  index sexo  posse_de_veiculo  posse_de_imovel  \
# 0           0  2015-01-01   8682    F             False             True
# 1           1  2015-01-01  12830    M              True             True
# 2           2  2015-01-01   2885    M              True             True
# 3           3  2015-01-01  16168    F              True            False
# 4           4  2015-01-01  12438    M             False            False
#
#    qtd_filhos   tipo_renda           educacao estado_civil tipo_residencia  \
# 0           1  Assalariado         Secundário       Casado            Casa
# 1           0   Empresário         Secundário       Casado            Casa
# 2           2  Assalariado  Superior completo       Casado            Casa
# 3           0   Empresário         Secundário       Casado            Casa
# 4           0  Assalariado         Secundário       Casado            Casa
#
#    idade  tempo_emprego  qt_pessoas_residencia    mau    renda
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'data_ref', 'index', 'sexo', 'posse_de_veiculo',
#        'posse_de_imovel', 'qtd_filhos', 'tipo_renda', 'educacao',
#        'estado_civil', 'tipo_residencia', 'idade', 'tempo_emprego',
#        'qt_pessoas_residencia', 'mau', 'renda'],
#       dtype='object')

# %%
df.shape
# Out:
# (15000, 16)

# %%
#analisando por mês
df['data_ref'] = pd.to_datetime(df['data_ref'])
df['ano_mes'] = df['data_ref'].dt.to_period('M')

ax = sns.countplot(x='ano_mes', hue='sexo', data=df)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
# Out:
# [Text(0, 0, '2015-01'),
#  Text(1, 0, '2015-02'),
#  Text(2, 0, '2015-03'),
#  Text(3, 0, '2015-04'),
#  Text(4, 0, '2015-05'),
#  Text(5, 0, '2015-06'),
#  Text(6, 0, '2015-07'),
#  Text(7, 0, '2015-08'),
#  Text(8, 0, '2015-09'),
#  Text(9, 0, '2015-10'),
#  Text(10, 0, '2015-11'),
#  Text(11, 0, '2015-12'),
#  Text(12, 0, '2016-01'),
#  Text(13, 0, '2016-02'),
#  Text(14, 0, '2016-03')]

# %% [markdown]
# R: Pelo gráfico parece haver estabilidade.

# %% [markdown]
# 2) Para cada variável qualitativa, construa um gráfico mostrando as médias de cada nível da variável no tempo e avalie a estabilidade. Houve alguma alteração importante? Você acha que se pode utilizar essas variáveis em uma modelagem?

# %% [markdown]
# Qualitativas:
#
# - 'sexo'
# - 'posse_de_veiculo'
# - 'posse_de_imovel
# - 'tipo_renda'
# - 'educacao'
# - 'estado_civil'
# - 'tipo_residencia'
# - 'mau'

# %%
df.head(1)
# Out:
#    Unnamed: 0   data_ref  index sexo  posse_de_veiculo  posse_de_imovel  \
# 0           0 2015-01-01   8682    F             False             True
#
#    qtd_filhos   tipo_renda    educacao estado_civil tipo_residencia  idade  \
# 0           1  Assalariado  Secundário       Casado            Casa     36
#
#    tempo_emprego  qt_pessoas_residencia    mau    renda data_ref_agrupada  \
# 0       3.575342                    3.0  False  3369.24           2015-01
#
#    ano_mes
# 0  2015-01

# %%
estado_civil = 'estado_civil'

plt.figure(figsize=(12, 6))
ax = sns.barplot(x='ano_mes', y='index', hue=estado_civil, data=df, ci=None)
plt.title(f'Média do {estado_civil} ao Longo do Tempo')
plt.show()
# Out:
# <ipython-input-34-36f94bb818ea>:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   ax = sns.barplot(x='ano_mes', y='index', hue=estado_civil, data=df, ci=None)

# %%
sexo = 'sexo'


plt.figure(figsize=(12, 6))
ax = sns.barplot(x='ano_mes', y='index', hue = sexo, data=df, ci=None)
plt.title(f'Médias de {sexo} ao Longo do Tempo')
plt.show()
# Out:
# <ipython-input-35-f4991085c393>:5: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   ax = sns.barplot(x='ano_mes', y='index', hue = sexo, data=df, ci=None)

# %%
posse_de_veiculo = 'posse_de_veiculo'
plt.figure(figsize=(12, 6))
ax = sns.barplot(x='ano_mes', y='index', hue = posse_de_veiculo, data=df, ci=None)
plt.title(f'Médias de {posse_de_veiculo} ao Longo do Tempo')
plt.show()
# Out:
# <ipython-input-36-62142e7bcffc>:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   ax = sns.barplot(x='ano_mes', y='index', hue = posse_de_veiculo, data=df, ci=None)

# %%
posse_de_imovel = 'posse_de_imovel'

plt.figure(figsize=(12, 6))
ax = sns.barplot(x='ano_mes', y='index', hue=posse_de_imovel, data=df, ci=None)
plt.title(f'Médias de {posse_de_imovel} ao Longo do Tempo')
plt.show()
# Out:
# <ipython-input-37-aeffa6da2fa0>:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   ax = sns.barplot(x='ano_mes', y='index', hue=posse_de_imovel, data=df, ci=None)

# %%
tipo_renda = 'tipo_renda'

plt.figure(figsize=(12, 6))
ax = sns.barplot(x='ano_mes', y='index', hue = tipo_renda, data=df, ci=None)
plt.title(f'Médias de {tipo_renda} ao Longo do Tempo')
plt.show()
# Out:
# <ipython-input-38-298120f2750d>:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   ax = sns.barplot(x='ano_mes', y='index', hue=tipo_renda, data=df, ci=None)

# %%
educacao = 'educacao'

plt.figure(figsize=(12, 6))
ax = sns.barplot(x='ano_mes', y='index', hue = educacao, data=df, ci=None)
plt.title(f'Médias de {educacao} ao Longo do Tempo')
plt.show()
# Out:
# <ipython-input-39-9cfc16fb53eb>:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   ax = sns.barplot(x='ano_mes', y='index', hue = educacao, data=df, ci=None)

# %%
tipo_residencia = 'tipo_residencia'

plt.figure(figsize=(12, 6))
ax = sns.barplot(x='ano_mes', y='index', hue = tipo_residencia, data=df, ci=None)
plt.title(f'Médias de {tipo_residencia} ao Longo do Tempo')
plt.show()
# Out:
# <ipython-input-40-da428a3afd6e>:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   ax = sns.barplot(x='ano_mes', y='index', hue = tipo_residencia, data=df, ci=None)

# %%
mau = 'mau'

plt.figure(figsize=(12, 6))
ax = sns.barplot(x='ano_mes', y='index', hue = mau, data=df, ci=None)
plt.title(f'Médias de {mau} ao Longo do Tempo')
plt.show()
# Out:
# <ipython-input-41-8ac81680cebd>:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   ax = sns.barplot(x='ano_mes', y='index', hue = mau, data=df, ci=None)

# %%
comparacao = 'mau'

plt.figure(figsize=(12, 6))
ax = sns.barplot(x='ano_mes', y='renda', hue = comparacao, data=df, ci=None)
plt.title(f'Médias de {comparacao} ao Longo do Tempo')
plt.show()
# Out:
# <ipython-input-42-e0c62d04e34a>:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   ax = sns.barplot(x='ano_mes', y='renda', hue = comparacao, data=df, ci=None)

# %% [markdown]
# R: Depois que criei a coluna ano_mes consegui enxergar melhor as variáveis ao longo do tempo. Ao final, comparei a coluna 'mau' com a renda, por data, e notei algumas diferenças ao longo do mês. Com isso, penso que são variáveis que dá sim para usar wm uma modelagem e analisar mais profundamente.
